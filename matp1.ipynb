# %% [markdown]
# <a href="https://colab.research.google.com/github/yakshithav/internship/blob/master/matp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pyplot**
#
# Generating visualizations with pyplot is very quick

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some number')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %% [markdown]
# Formatting the style of your plot

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np
t=np.arange(0.,5.,0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^',t,t**4,'ro')
plt.show()

# %%
data={'a':np.arange(50),
     'c':np.random.randint(0,50,50),
     'd':np.random.randn(50)}
data['b']=data['a']+200*np.random.randn(50)
data['d']=np.abs(data['d'])*250

plt.scatter('a','b',c='c',s='d',data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# **Plotting with categorical variables**

# %%
names=['group_a','group_b','group_c']
values=[1,10,100]

plt.figure(figsize=(9,3))

plt.subplot(131)
plt.bar(names,values)
plt.subplot(132)
plt.scatter(names,values)
plt.subplot(133)
plt.plot(names,values)
plt.suptitle('categorical plotting')
plt.show()

# %% [markdown]
# Simple Line plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt. figure()
ax=plt. axes()

x=np.linspace(0, 10 ,1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# Adjusting the plot :line colors and styles

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')
plt.plot(x, np.sin(x - 2), color='0.75')       
plt.plot(x, np.sin(x - 3), color='#FFDD44')    
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) 
plt.plot(x, np.sin(x - 5), color='chartreuse');

# %%
plt.plot(x, np.sin(x - 0), color='r')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g');

# %%
plt.plot(x, np.sin(x - 0), color='blue');

# %%
plt.plot(x, np.sin(x - 1), color='g');

# %%
plt.plot(x, np.sin(x - 2), color='0.75');

# %%
plt.plot(x, np.sin(x - 3), color='#FFDD44');

# %%
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3));

# %%
plt.plot(x, np.sin(x - 5), color='chartreuse');

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')

# %%
plt.plot(x, x + 0, linestyle='solid');

# %%
plt.plot(x, x + 1, linestyle='dashed');
